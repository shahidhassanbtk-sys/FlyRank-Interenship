# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/shahidhassanbtk-sys/FlyRank-Interenship/blob/main/work/notebooks/w01_research_question.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# *Name your lane — or say 'freestyle' and describe your own question. One short paragraph: why this one?*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
import os, sys, subprocess

IN_COLAB = "google.colab" in sys.modules
REPO_URL = "https://github.com/shahidhassanbtk-sys/FlyRank-Interenship"   # your actual repo URL
REPO_DIR = "FlyRank-Interenship"                                      # your actual repo folder name

if IN_COLAB:
    if not os.path.isdir(REPO_DIR):
        subprocess.run(["git", "clone", "--depth", "1", REPO_URL, REPO_DIR], check=True)
    os.chdir(REPO_DIR)
elif os.path.basename(os.getcwd()) == "notebooks":
    os.chdir("..")

print("Current working directory:", os.getcwd())
# Out:
# Current working directory: /content/FlyRank-Interenship

# %%
import pandas as pd
df = pd.read_csv("data/raw/content_refresh_anonymized.csv")
print("Dataset loaded:", df.shape[0], "rows,", df.shape[1], "columns")
# Out:
# Dataset loaded: 30000 rows, 44 columns

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve? Who acts on it? What does a wrong recommendation cost?*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
flagged = df[(df["days_since_last_update"] >= 180) & (df["impressions_90d"] >= 500)]
print("Pages that would be flagged for review:", flagged.shape[0])
print("Share of total pages:", round(flagged.shape[0] / df.shape[0], 3))
# Out:
# Pages that would be flagged for review: 17
# Share of total pages: 0.001

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
df["is_declining_label"] = df["trend_direction"].str.lower().eq("down").astype(int)

print("Overall declining rate:", round(df["is_declining_label"].mean(), 3))
print("Declining rate among stale pages (180+ days no update):",
      round(df[df["days_since_last_update"] >= 180]["is_declining_label"].mean(), 3))
print("Declining rate among high-impression pages (500+ impressions):",
      round(df[df["impressions_90d"] >= 500]["is_declining_label"].mean(), 3))
# Out:
# Overall declining rate: 0.542
# Declining rate among stale pages (180+ days no update): 0.471
# Declining rate among high-impression pages (500+ impressions): 0.596

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
# Recreate flagged now that is_declining_label exists
flagged = df[(df["days_since_last_update"] >= 180) & (df["impressions_90d"] >= 500)]

precision = flagged["is_declining_label"].mean()
print("Of flagged pages, share that are actually declining:", round(precision, 3))
print("Share that would be reviewed unnecessarily:", round(1 - precision, 3))
# Out:
# Of flagged pages, share that are actually declining: 0.941
# Share that would be reviewed unnecessarily: 0.059

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
